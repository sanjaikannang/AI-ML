# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 4.6 MB/s eta 0:00:03
#    ---- ----------------------------------- 1.3/11.5 MB 2.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.5 MB 3.1 MB/s eta 0:00:04
#    --------- ------------------------------ 2.6/11.5 MB 3.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.1/11.5 MB 3.0 MB/s eta 0:00:03
#    ------------- -------------------------- 3.9/11.5 MB 3.0 MB/s eta 0:00:03
#    --------------- ------------------------ 4.5/11.5 MB 3.0 MB/s eta 0:00:03
#    ------------------ --------------------- 5.2/11.5 MB 3.1 MB/s eta 0:00:03
#    --------------------- ------------------ 6.0/11.5 MB 3.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 6.8/11.5 MB 3.3 MB/s eta 0:00:02
#    -------------------------- ------------- 7.6/11.5 MB 3.3 MB/s eta 0:00:02
# ...

# %%
import pandas as pd

# %%
import pandas as pd

data = [{
    "name": "sanjai",
    "email": "sanjai@gmail.com",
    "age": 22
},
{
    "name": "siva",
    "email": "siva@gmail.com",
    "age": 23
}]

result = pd.DataFrame(data)
print(result)
# Out:
#      name             email  age
# 0  sanjai  sanjai@gmail.com   22
# 1    siva    siva@gmail.com   23

# %%
import pandas as pd

data = [{
    "name": "sanjai",
    "email": "sanjai@gmail.com",
    "course": "Python"
},
{
    "name": "kannan",
    "email": "kannan@gmail.com",
    "course": "MERN"
},
{
    "name": "siva",
    "email": "siva@gmail.com",
    "course": "Data Science"
},
{
    "name": "Rahul",
    "email": "Rahul@gmail.com",
    "course": "C++"
},
{
    "name": "Ajay",
    "email": "Ajay@gmail.com",
    "course": "AI & ML"
}]

result = pd.DataFrame(data)
print(result)
# Out:
#      name             email        course
# 0  sanjai  sanjai@gmail.com        Python
# 1  kannan  kannan@gmail.com          MERN
# 2    siva    siva@gmail.com  Data Science
# 3   Rahul   Rahul@gmail.com           C++
# 4    Ajay    Ajay@gmail.com       AI & ML

# %%
df = pd.DataFrame()

df["Name"] = ["Sanjai", "Siva", "Kannan", "Rahul", "Ajay"]
df["age"] = [22, 23, 24, 25, 26]
df
# Out:
#      Name  age
# 0  Sanjai   22
# 1    Siva   23
# 2  Kannan   24
# 3   Rahul   25
# 4    Ajay   26

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
result
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd

result = pd.read_excel(r"D:\AI & ML Learning\Day-1\Module_4\Day-1\stock.xlsx")

result
# Out:
#      INVESTMENT VALUES     Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4
# 0                  NaN            NaN        NaN        NaN        NaN
# 1                  NaN            NaN        NaN        NaN        NaN
# 2          Corporation  Ticker Symbol      Price     Shares      Value
# 3          Amazon.com            AMZN        NaN        250          0
# 4           Home Depot             HD        NaN        300          0
# 5                Intel           INTC        NaN        300          0
# 6  Johnson and Johnson            JNJ        NaN        100          0
# 7            Microsoft           MSFT        NaN        200          0
# 8                  NaN            NaN        NaN        NaN          0

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
result
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
print(result.head(10)) # First 10 rows
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
# 5  2023                     Level 1                99999       All industries
# 6  2023                     Level 1                99999       All industries
# 7  2023                     Level 1                99999       All industries
# 8  2023                     Level 1                99999       All industries
# 9  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# ...

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
print(result.tail(10)) # Last 10 rows
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50975  2013                     Level 3                 ZZ11
# 50976  2013                     Level 3                 ZZ11
# 50977  2013                     Level 3                 ZZ11
# 50978  2013                     Level 3                 ZZ11
# 50979  2013                     Level 3                 ZZ11
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 50975  Food product manufacturing  Dollars (millions)           H32
# 50976  Food product manufacturing  Dollars (millions)           H33
# 50977  Food product manufacturing             Dollars           H34
# ...

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
print(result.info()) # Information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB
# None

# %%
import pandas as pd

result = pd.read_csv(r"c:\Users\sanja_m20ck7b\Downloads\annual-enterprise-survey-2023-financial-year-provisional.csv")
print(result.describe()) # Description of the data
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000
