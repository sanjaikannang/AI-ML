# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

result = pd.read_csv(r'D:\AI & ML Learning\Day-1\Module_4\Day-2\annual-enterprise-survey-2023.csv')
result
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2023                     Level 1                99999
# 1      2023                     Level 1                99999
# 2      2023                     Level 1                99999
# 3      2023                     Level 1                99999
# 4      2023                     Level 1                99999
# ...     ...                         ...                  ...
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
# Display the first 100 rows of the dataset

import pandas as pd

result = pd.read_csv(r'D:\AI & ML Learning\Day-1\Module_4\Day-2\annual-enterprise-survey-2023.csv')
output = result.head(100)

# Display the Units column
output = result['Units'].unique()
output
# Out:
# array(['Dollars (millions)', 'Dollars', 'Percentage'], dtype=object)
