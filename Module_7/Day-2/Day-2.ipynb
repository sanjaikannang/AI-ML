# %%
# %pip install seaborn
# %pip install matplotlib
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("iris")
result
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")
result
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")

sns.scatterplot(data=result)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")

sns.scatterplot(data=result, x="total_bill", y="tip", hue="sex", style="day", size="size")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("flights")

sns.lineplot(data=result, x="year", y="passengers", hue="month")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("flights")

sns.barplot(data=result, x="year", y="passengers", hue="month")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("flights")

sns.scatterplot(data=result, x="year", y="passengers", hue="month")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")

sns.boxplot(data=result, x="day", y="total_bill")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")

sns.histplot(data=result, x="total_bill")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

result = sns.load_dataset("tips")

sns.violinplot(data=result, x="day", y="tip", hue="sex")

plt.show()

# %%
import pandas as pd
import seaborn as sns

result = sns.load_dataset("flights")
data = pd.pivot_table(data=result, index="year", columns="month")
sns.heatmap(data)

plt.show()
# Out:
# C:\Users\sanja_m20ck7b\AppData\Local\Temp\ipykernel_6304\3350310935.py:5: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data = pd.pivot_table(data=result, index="year", columns="month")

# %%
# Out:
# C:\Users\sanja_m20ck7b\AppData\Local\Temp\ipykernel_6304\482925538.py:5: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   data = pd.pivot_table(data=result, index="year", columns="month")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[36], line 6
#       4 result = sns.load_dataset("flights")
#       5 data = pd.pivot_table(data=result, index="year", columns="month")
# ----> 6 sns.clustermap(data)
#       8 plt.show()
#
# ...

# %%
# %pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 5
#       2 import seaborn as sns
#       4 result = sns.load_dataset("flights")
# ----> 5 data = pd.pivot_table(data=result)
#       6 sns.clustermap(data)
#       8 plt.show()
#
# File c:\Users\sanja_m20ck7b\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
# ...
